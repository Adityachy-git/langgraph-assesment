# %% [markdown]
# # Stock Market Analysis Agent Demo
#
# ## 1. Project Overview
#
# This notebook demonstrates the stock analysis workflow, from fetching historical data to producing a BUY, HOLD, or SELL recommendation.
#
# ## 2. Architecture
#
# The project is split into four stages: fetch stock data, calculate indicators, generate a recommendation, and format the final report. The shared state keeps each step simple and testable.

# %%
import pandas as pd

from components.indicators import calculate_indicators

sample_prices = pd.DataFrame({"Close": list(range(100, 160))})
indicators = calculate_indicators(sample_prices)
print(indicators)
# Out:
# {'current_price': 159.0, 'sma_10': 154.5, 'sma_20': 149.5, 'rsi_14': 100.0}

# %% [markdown]
# ## 3. Implementation
#
# The helper functions normalize the ticker symbol, validate stock history, and apply the recommendation rule set in a transparent way.
#
# ## 4. Test Cases
#
# The automated test suite covers valid data loading, invalid ticker handling, empty responses, API failures, and indicator correctness.

# %%
from components.helper_functions import derive_recommendation, format_currency, format_numeric

recommendation, reason = derive_recommendation(
    indicators["sma_10"],
    indicators["sma_20"],
    indicators["rsi_14"],
)

print(f"Current price: {format_currency(indicators['current_price'])}")
print(f"SMA 10: {format_numeric(indicators['sma_10'])}")
print(f"SMA 20: {format_numeric(indicators['sma_20'])}")
print(f"RSI 14: {format_numeric(indicators['rsi_14'])}")
print(f"Recommendation: {recommendation}")
print(f"Reason: {reason}")
# Out:
# Current price: $159.00
# SMA 10: 154.50
# SMA 20: 149.50
# RSI 14: 100.00
# Recommendation: HOLD
# Reason: Momentum and RSI signals do not provide a clear directional edge.

# %% [markdown]
# ## 5. Results
#
# The demonstration shows the indicator pipeline working end to end and produces a clean report format that mirrors the CLI output.
#
# ## 6. Conclusion
#
# This project is ready for assessment: it has a deterministic core, test coverage, a clean README, and notebook output that reviewers can inspect quickly.

# %%
assert round(indicators["current_price"], 2) == 159.00
assert round(indicators["sma_10"], 2) == 154.50
assert round(indicators["sma_20"], 2) == 149.50
assert indicators["rsi_14"] == 100.0
print("Sample assertions passed.")
# Out:
# Sample assertions passed.
